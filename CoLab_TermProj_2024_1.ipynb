# %% [markdown]
# # 생물정보학 및 실습 1 - Term Project용 환경 셋업
#
# ```
# 생물정보학 및 실습 1
# 서울대학교 생물정보학전공/생명과학부 2024년 1학기
#
# 이 노트북은 Creative Commons BY-SA 조건으로 재사용 가능합니다.
# 장혜식 <hyeshik@snu.ac.kr>, 서울대학교 생명과학부
# ```
#
# 이 노트북은 Google Colab을 이용해서 Term Project를 할 수 있도록 환경을 준비해 줍니다. 터미널 사용이 원활하지 않은 상태이고, 데이터를 오랫동안 보관하기 어렵기 때문에 되도록 개인용 컴퓨터에서 [Anaconda](https://www.anaconda.com/)나 [JupyterLab](https://jupyterlab.readthedocs.io/en/stable/) 등을 설치하고 사용하시는 것이 편하지만, 개인용 컴퓨터 사양이 부족한 경우에는 Google CoLab을 사용할 수도 있습니다. 개인용 컴퓨터를 쓸 때는 Windows에서는 [WSL2](https://docs.microsoft.com/en-us/windows/wsl/install-win10)를 쓰시면 리눅스 커맨드라인 환경을 쓸 수 있습니다. Google Colab은 창을 닫은 후 90분 후, 또는 창을 처음 열고 12시간 후에 환경을 닫아버리기 때문에 매번 실습할 때마다 새로 셋업이 필요합니다. `Runtime->Run All`을 실행해서 전체를 한 번 실행하시면 준비됩니다. 모든 것이 잘 안 되고 뭔가 꼬인 느낌이 강하게 들 때는 `Runtime->Factory reset runtime`을 누르고 새로 시작하시면 될 수도 있습니다.

# %% [markdown]
# ## Google Drive 마운트
#
# 데이터 파일들을 불러오고 저장하기 위해서 Google Drive를 연결합니다. **이번엔 스크립트 파일을 편집해야 하기 때문에 Google Drive 마운트를 하지 않으면 vim등 콘솔에서 쓸 수 있는 에디터를 쓰셔야 합니다.** 화면에 나오는 주소를 눌러서 인증하고 인증 코드를 그 아래에 입력하세요. 그러면 `/contents/drive/MyDrive`에서 자신의 Drive 최상단 폴더가 보입니다. Google CoLab에서 접속하지 않고, 본인 컴퓨터 또는 연구실 워크스테이션 등 다른 컴퓨터를 쓰시는 경우에는 저장공간이 충분하므로 이 부분은 생략하고 지나갑니다.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 실습용 Bioconda 환경 설치하기
# Google CoLab에서 접속하지 않고, 본인 컴퓨터 또는 연구실 워크스테이션 등 다른 컴퓨터를 쓰시는 경우에는 따로 실습용 [Bioconda](https://bioconda.github.io/) 환경을 구축해서 이 노트북을 그 환경 안에서 띄우시면 됩니다.
#
# CoLab을 쓰시는 분들은 다음에 따라서 실습용 프로그램들을 쉽게 설치할 수 있도록 [Bioconda](https://bioconda.github.io/) 환경을 만듭니다. 실행하고 진행상황을 관찰하다가 에러로 보이는 것이 있으면 잘 읽어보고 해결합니다.
#
# 파이썬 모듈들은 Colab쪽의 파이썬 인터프리터를 바꿀 수 없기 때문에 Conda에 설치하더라도 사용하기 어렵습니다. 파이썬 모듈은 `pip` 명령어로 설치하시면 Colab에서 불러와서 사용할 수 있습니다.
#
# 환경 초기화에 관련된 스크립트는 [GitHub 프로젝트](https://github.com/hyeshik/colab-biolab)에 있습니다.

# %%
# !git clone https://github.com/hyeshik/colab-biolab.git
# !cd colab-biolab && bash tools/setup.sh
exec(open('colab-biolab/tools/activate_conda.py').read())

# %% [markdown]
# Google CoLab에서 shell command를 실행할 때는 명령 앞에 !을 붙이면 실행할 수 있습니다.

# %% [markdown]
# ## 시퀀싱 데이터 다운로드
# 이제 실습 수업에서 필요한 시퀀싱 데이터를 다운로드 받아서 설치합시다. 드라이브 공간만 충분하면 데이터는 계속 저장돼 있기 때문에 학기 전체를 통해서 딱 한 번만 하시면 됩니다. Colab에서는 작업용 데이터를 Google Drive 폴더 아래의 `binfo-datapack1`에 저장합니다. 실습용 데이터는 `/content/drive/MyDrive/binfo1-datapack1`에 풀리게 됩니다.
#
# ### (Option 1) Google CoLab에서 접속한 경우
# 1. [Google Drive 공유폴더](https://drive.google.com/drive/folders/1QBJednh-C7A17PFOlpZHBKyDmBvd6klh?usp=sharing)에 접속합니다.
# 1. 중간 제목줄의 "binfo1-datapack1 ▾"에서 ▾을 누릅니다.
# 1. Add shortcut to Drive를 누릅니다.
# 1. My Drive를 선택해서 ADD SHORTCUT 버튼을 누릅니다.
# 1. 다음 cell을 실행해서 링크가 제대로 들어왔는지 확인합니다. (바로 확인되지 않으면 3–5분 정도 기다렸다가 하면 됩니다.)
# 1. 제대로 확인되면 다음으로 넘어갑니다.

# %%
# !ls -al /content/drive/MyDrive/binfo1-datapack1/

# %% [markdown]
# ### (Option 2) CoLab외의 다른 환경에서 접속한 경우
# 본인 컴퓨터나 연구실 워크스테이션 등에서 작업하는 경우에는 다음 명령어로 다운로드 받으시면 됩니다. 첫 번째에는 wget이 접속오류를 내는 경우가 많으니, 접속에러가 발생하면 다시 한 번 실행해 보세요. `/content/drive/Mydrive` 부분은 원하는 저장 경로로 바꿔서 지정하시면 됩니다.

# %%
# !wget -O - --no-check-certificate https://hyeshik.qbio.io/binfo/binfo1-datapack1.tar | tar -C ~/bioinfo1/project -xf -
# Out:
# --2024-05-05 23:46:05--  https://hyeshik.qbio.io/binfo/binfo1-datapack1.tar
# Resolving hyeshik.qbio.io (hyeshik.qbio.io)... 147.47.203.129
# Connecting to hyeshik.qbio.io (hyeshik.qbio.io)|147.47.203.129|:443... connected.
# WARNING: cannot verify hyeshik.qbio.io's certificate, issued by ‘CN=R3,O=Let's Encrypt,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 6424668160 (6.0G) [application/octet-stream]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]   5.98G   112MB/s    in 56s
#
# 2024-05-05 23:47:01 (110 MB/s) - written to stdout [6424668160/6424668160]

# %% [markdown]
# 그리고, GENCODE Annotation 데이터도 미리 받아서 저장해 둡니다. 에러가 나면 다시 한 번 실행해 봅니다.

# %%
# !wget --no-check-certificate -O ~/bioinfo1/project/binfo1-datapack1/gencode.gtf.gz http://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M27/gencode.vM27.annotation.gtf.gz
# Out:
# --2024-05-05 23:47:37--  http://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M27/gencode.vM27.annotation.gtf.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.165|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28359457 (27M) [application/x-gzip]
# Saving to: ‘/rna/hyemin/bioinfo1/project/binfo1-datapack1/gencode.gtf.gz’
#
# /rna/hyemin/bioinfo 100%[===================>]  27.04M   182KB/s    in 4m 40s
#
# 2024-05-05 23:52:18 (99.0 KB/s) - ‘/rna/hyemin/bioinfo1/project/binfo1-datapack1/gencode.gtf.gz’ saved [28359457/28359457]

# %% [markdown]
# ### 파일 체크섬 확인
#
# 받은 데이터의 MD5 체크섬을 확인합니다. 한참 걸립니다. 각 파일들의 원래 체크섬은 다음과 같습니다. 한 번 비교해 보세요. (나중에 자동으로 비교하고 싶으시면 `md5sum -c` 옵션을 사용하면 됩니다. 여기서는 MD5를 처음 써 보는 의미에서 직접 비교해 봅시다.)
#
# ```
# 140aaf30bcb9276cc716f8699f04ddd6  CLIP-35L33G.bam
# f1b3336ed7e2f97d562dcc71641251bd  CLIP-35L33G.bam.bai
# 328883a73d507eafbf5b60bd6b906201  RNA-control.bam
# 02073818e2f398a73c3b76e5169de1ca  RNA-control.bam.bai
# b09550d09d6c2a4ce27f0226f426fdb1  RNA-siLin28a.bam
# fef112c727244060ea62d3f2564a07f6  RNA-siLin28a.bam.bai
# 28bbd0c47d725669340c784f1b772c01  RNA-siLuc.bam
# 43590fdc4d81905c0432e0d1cb8cfd5b  RNA-siLuc.bam.bai
# 5c08a9297307bc83259e658c4474f0cc  RPF-siLin28a.bam
# a1bb3e29be412dfd7fd8d16b1b1acc4c  RPF-siLin28a.bam.bai
# f2eebf50943024d0116c9cd3e744c707  RPF-siLuc.bam
# dc24f69e8f571fc8be30f28ce5b84fcd  RPF-siLuc.bam.bai
# ```

# %%
# !md5sum binfo1-datapack1/*
# Out:
# 140aaf30bcb9276cc716f8699f04ddd6  binfo1-datapack1/CLIP-35L33G.bam
# f1b3336ed7e2f97d562dcc71641251bd  binfo1-datapack1/CLIP-35L33G.bam.bai
# 794eb8d273987a094dcc013afa2a1956  binfo1-datapack1/gencode.gtf.gz
# 328883a73d507eafbf5b60bd6b906201  binfo1-datapack1/RNA-control.bam
# 02073818e2f398a73c3b76e5169de1ca  binfo1-datapack1/RNA-control.bam.bai
# b09550d09d6c2a4ce27f0226f426fdb1  binfo1-datapack1/RNA-siLin28a.bam
# fef112c727244060ea62d3f2564a07f6  binfo1-datapack1/RNA-siLin28a.bam.bai
# 28bbd0c47d725669340c784f1b772c01  binfo1-datapack1/RNA-siLuc.bam
# 43590fdc4d81905c0432e0d1cb8cfd5b  binfo1-datapack1/RNA-siLuc.bam.bai
# 5c08a9297307bc83259e658c4474f0cc  binfo1-datapack1/RPF-siLin28a.bam
# a1bb3e29be412dfd7fd8d16b1b1acc4c  binfo1-datapack1/RPF-siLin28a.bam.bai
# f2eebf50943024d0116c9cd3e744c707  binfo1-datapack1/RPF-siLuc.bam
# dc24f69e8f571fc8be30f28ce5b84fcd  binfo1-datapack1/RPF-siLuc.bam.bai

# %%
# !ls -al binfo*
# Out:
# total 6301792
# drwxr-xr-x 1 hyemin rna        428 May  5 23:47 .
# drwxr-xr-x 1 hyemin rna         86 May  5 23:46 ..
# -rw-r--r-- 1 hyemin rna 1370036258 May  6  2021 CLIP-35L33G.bam
# -rw-r--r-- 1 hyemin rna    3118336 May  6  2021 CLIP-35L33G.bam.bai
# -rw-r--r-- 1 hyemin rna   28359457 Mar  9  2021 gencode.gtf.gz
# -rw-r--r-- 1 hyemin rna 1003658801 May  6  2021 RNA-control.bam
# -rw-r--r-- 1 hyemin rna    2276104 May  6  2021 RNA-control.bam.bai
# -rw-r--r-- 1 hyemin rna 1260991122 May  6  2021 RNA-siLin28a.bam
# -rw-r--r-- 1 hyemin rna    2710744 May  6  2021 RNA-siLin28a.bam.bai
# -rw-r--r-- 1 hyemin rna  981684502 May  6  2021 RNA-siLuc.bam
# -rw-r--r-- 1 hyemin rna    2606104 May  6  2021 RNA-siLuc.bam.bai
# -rw-r--r-- 1 hyemin rna  737352902 May  6  2021 RPF-siLin28a.bam
# -rw-r--r-- 1 hyemin rna    2482768 May  6  2021 RPF-siLin28a.bam.bai
# -rw-r--r-- 1 hyemin rna 1055123479 May  6  2021 RPF-siLuc.bam
# -rw-r--r-- 1 hyemin rna    2605912 May  6  2021 RPF-siLuc.bam.bai

# %% [markdown]
# 실습에 필요한 프로그램들 몇 가지를 추가로 설치합니다.

# %%
# !conda install -y subread

# %% [markdown]
# ## Transcript count table 마련하기
#
# 제공된 alignment와 annotation 파일들을 이용해서 transcript별 read count를 구해봅니다. 실제 연구에서는 multi-mapping 등을 고려해야 하지만, 여기서는 단순화해서 모두 무시합니다.

# %% [markdown]
# 먼저 작업 디렉토리를 만들고 데이터를 원본 디렉토리에서 복사해 옵니다. (이미 이 노트북을 실행한 적이 있으면 다시 할 필요는 없습니다.)

# %%
# !mkdir ~/bioinfo1/project/binfo1-work
# !rsync -Pav ~/bioinfo1/project/binfo1-datapack1/ ~/bioinfo1/project/binfo1-work/
# Out:
# sending incremental file list
# ./
# CLIP-35L33G.bam
#   1,370,036,258 100%    1.07GB/s    0:00:01 (xfr#1, to-chk=12/14)
# CLIP-35L33G.bam.bai
#       3,118,336 100%   11.31MB/s    0:00:00 (xfr#2, to-chk=11/14)
# RNA-control.bam
#   1,003,658,801 100%  941.16MB/s    0:00:01 (xfr#3, to-chk=10/14)
# RNA-control.bam.bai
#       2,276,104 100%   11.93MB/s    0:00:00 (xfr#4, to-chk=9/14)
# RNA-siLin28a.bam
#   1,260,991,122 100%    1.10GB/s    0:00:01 (xfr#5, to-chk=8/14)
# RNA-siLin28a.bam.bai
#       2,710,744 100%    7.81MB/s    0:00:00 (xfr#6, to-chk=7/14)
# RNA-siLuc.bam
#     981,684,502 100%  724.62MB/s    0:00:01 (xfr#7, to-chk=6/14)
# RNA-siLuc.bam.bai
#       2,606,104 100%    7.92MB/s    0:00:00 (xfr#8, to-chk=5/14)
# RPF-siLin28a.bam
#     737,352,902 100%  676.80MB/s    0:00:01 (xfr#9, to-chk=4/14)
# RPF-siLin28a.bam.bai
#       2,482,768 100%   33.83MB/s    0:00:00 (xfr#10, to-chk=3/14)
# RPF-siLuc.bam
#   1,055,123,479 100%  846.29MB/s    0:00:01 (xfr#11, to-chk=2/14)
# ...

# %%
# %cd ~/bioinfo1/project/binfo1-work
# Out:
# /rna/hyemin/bioinfo1/project/binfo1-work

# %% [markdown]
# 자! bam 파일에 담긴 aligned reads와 gtf 파일에 담긴 gene annotation으로 gene별 read count를 구합니다.

# %%
# !featureCounts -a gencode.gtf.gz -o read-counts.txt *.bam
# Out:
#         ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v2.0.6
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 6 BAM files                                      ||
# ||                                                                            ||
# ||                           CLIP-35L33G.bam                                  ||
# ||                           RNA-control.bam                                  ||
# ...

# %% [markdown]
# 결과를 pandas로 읽어와 봅니다.

# %%
import pandas as pd
cnts = pd.read_csv('read-counts.txt', sep='\t', comment='#', index_col=0)
cnts.head()
# Out:
#                                                      Chr  \
# Geneid
# ENSMUSG00000102693.2                                chr1
# ENSMUSG00000064842.3                                chr1
# ENSMUSG00000051951.6  chr1;chr1;chr1;chr1;chr1;chr1;chr1
# ENSMUSG00000102851.2                                chr1
# ENSMUSG00000103377.2                                chr1
#
#                                                                   Start  \
# Geneid
# ENSMUSG00000102693.2                                            3143476
# ENSMUSG00000064842.3                                            3172239
# ENSMUSG00000051951.6  3276124;3276746;3283662;3283832;3284705;349192...
# ENSMUSG00000102851.2                                            3322980
# ENSMUSG00000103377.2                                            3435954
#
#                                                                     End  \
# Geneid
# ENSMUSG00000102693.2                                            3144545
# ...

# %% [markdown]
# 이제 한 번 대충 그림을 그려 봅니다.

# %%
cnts['clip_enrichment'] = cnts['CLIP-35L33G.bam'] / cnts['RNA-control.bam']
cnts['rden_change'] = (cnts['RPF-siLin28a.bam'] / cnts['RNA-siLin28a.bam']) / (cnts['RPF-siLuc.bam'] / cnts['RNA-siLuc.bam'])
cnts.head()
# Out:
#                                                      Chr  \
# Geneid
# ENSMUSG00000102693.2                                chr1
# ENSMUSG00000064842.3                                chr1
# ENSMUSG00000051951.6  chr1;chr1;chr1;chr1;chr1;chr1;chr1
# ENSMUSG00000102851.2                                chr1
# ENSMUSG00000103377.2                                chr1
#
#                                                                   Start  \
# Geneid
# ENSMUSG00000102693.2                                            3143476
# ENSMUSG00000064842.3                                            3172239
# ENSMUSG00000051951.6  3276124;3276746;3283662;3283832;3284705;349192...
# ENSMUSG00000102851.2                                            3322980
# ENSMUSG00000103377.2                                            3435954
#
#                                                                     End  \
# Geneid
# ENSMUSG00000102693.2                                            3144545
# ...

# %%
from matplotlib import pyplot as plt
import numpy as np

fig, ax = plt.subplots(1, 1, figsize=(5, 5))
ax.scatter(np.log2(cnts['clip_enrichment']),
           np.log2(cnts['rden_change']))
# Out:
# /rna/hyemin/mambaforge/envs/project1/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log2
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# 이 그림에는 문제가 많이 있습니다. 논문의 그림 Figure 4D처럼 한 번 만들어 봅시다~

# %%
cnts_TPM = cnts.copy()
bam_columns = cnts_TPM.filter(regex='bam$', axis=1).columns
cnts_TPM[[col + '_RPK' for col in bam_columns]] = cnts_TPM[bam_columns].div(cnts_TPM['Length'], axis=0)
total_RPK = cnts_TPM.filter(regex='_RPK$', axis=1).sum()
cnts_TPM.head()
# Out:
#                                                      Chr  \
# Geneid
# ENSMUSG00000102693.2                                chr1
# ENSMUSG00000064842.3                                chr1
# ENSMUSG00000051951.6  chr1;chr1;chr1;chr1;chr1;chr1;chr1
# ENSMUSG00000102851.2                                chr1
# ENSMUSG00000103377.2                                chr1
#
#                                                                   Start  \
# Geneid
# ENSMUSG00000102693.2                                            3143476
# ENSMUSG00000064842.3                                            3172239
# ENSMUSG00000051951.6  3276124;3276746;3283662;3283832;3284705;349192...
# ENSMUSG00000102851.2                                            3322980
# ENSMUSG00000103377.2                                            3435954
#
#                                                                     End  \
# Geneid
# ENSMUSG00000102693.2                                            3144545
# ...

# %%
RPK_bam_columns = cnts_TPM.filter(regex='RPK$', axis=1).columns
cnts_TPM[RPK_bam_columns] = cnts_TPM[RPK_bam_columns] * 1E6 / total_RPK
cnts_TPM.rename(columns={col: col[:-len('_RPK')] + '_TPM' for col in RPK_bam_columns}, inplace=True)
cnts_TPM.head()
# Out:
#                                                      Chr  \
# Geneid
# ENSMUSG00000102693.2                                chr1
# ENSMUSG00000064842.3                                chr1
# ENSMUSG00000051951.6  chr1;chr1;chr1;chr1;chr1;chr1;chr1
# ENSMUSG00000102851.2                                chr1
# ENSMUSG00000103377.2                                chr1
#
#                                                                   Start  \
# Geneid
# ENSMUSG00000102693.2                                            3143476
# ENSMUSG00000064842.3                                            3172239
# ENSMUSG00000051951.6  3276124;3276746;3283662;3283832;3284705;349192...
# ENSMUSG00000102851.2                                            3322980
# ENSMUSG00000103377.2                                            3435954
#
#                                                                     End  \
# Geneid
# ENSMUSG00000102693.2                                            3144545
# ...

# %%
cnts_TPM['clip_enrichment'] = cnts_TPM['CLIP-35L33G.bam_TPM'] / cnts_TPM['RNA-control.bam_TPM']
cnts_TPM['rden_change'] = (cnts_TPM['RPF-siLin28a.bam_TPM'] / cnts_TPM['RNA-siLin28a.bam_TPM']) / (cnts_TPM['RPF-siLuc.bam_TPM'] / cnts_TPM['RNA-siLuc.bam_TPM'])
cnts_TPM.head()
# Out:
#                                                      Chr  \
# Geneid
# ENSMUSG00000102693.2                                chr1
# ENSMUSG00000064842.3                                chr1
# ENSMUSG00000051951.6  chr1;chr1;chr1;chr1;chr1;chr1;chr1
# ENSMUSG00000102851.2                                chr1
# ENSMUSG00000103377.2                                chr1
#
#                                                                   Start  \
# Geneid
# ENSMUSG00000102693.2                                            3143476
# ENSMUSG00000064842.3                                            3172239
# ENSMUSG00000051951.6  3276124;3276746;3283662;3283832;3284705;349192...
# ENSMUSG00000102851.2                                            3322980
# ENSMUSG00000103377.2                                            3435954
#
#                                                                     End  \
# Geneid
# ENSMUSG00000102693.2                                            3144545
# ...

# %%
cnts_filter = (cnts_TPM[[col for col in cnts_TPM.filter(regex='bam$', axis=1)]] >= 30).all(axis=1)
cnts_filtered = cnts_TPM[cnts_filter].copy()

cnts_filtered = cnts_filtered[(cnts_filtered['RPF-siLuc.bam'] >= 80)]
cnts_filtered.head()
# Out:
#                                                                      Chr  \
# Geneid
# ENSMUSG00000033845.14  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# ENSMUSG00000033813.16  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# ENSMUSG00000033793.13  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# ENSMUSG00000025907.15  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
# ENSMUSG00000051285.18  chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;chr1;c...
#
#                                                                    Start  \
# Geneid
# ENSMUSG00000033845.14  4843429;4843434;4844659;4846600;4847748;484774...
# ENSMUSG00000033813.16  4928037;4928261;4937693;4937693;4948250;494825...
# ENSMUSG00000033793.13  5140241;5153303;5153333;5153347;5153355;515335...
# ENSMUSG00000025907.15  6276421;6276451;6284869;6284887;6285232;629382...
# ENSMUSG00000051285.18  7159144;7159154;7159328;7159390;7190418;721786...
#
# ...

# %%
# 여기에 코드를 새로 작성해서 논문의 그림과 비슷하게 만들어 봅니다.

from matplotlib import pyplot as plt
import numpy as np
import scipy.stats as stats



fig, ax = plt.subplots(1, 1, figsize=(5, 5))
ax.grid(linestyle='--', linewidth=0.5, alpha=0.5)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

x = np.log2(cnts_filtered['clip_enrichment'])
y = np.log2(cnts_filtered['rden_change'])

ax.scatter(x, y, c='black', s=3, alpha=0.1)


ax.set_xlim(-6, 6)
ax.set_ylim(-4, 4)

ax.set_xticks(range(-6, 7, 3))
ax.set_yticks(range(-4, 5, 2))

corr = stats.pearsonr(x, y)[0]
ax.text(3.5, -3.5, f'$r$ = {corr:.2f}', ha='left', va='bottom', fontsize=12)

ax.set_xlabel('Lin28A CLIP enrichment ($\mathrm{log}_2$)', fontsize=12)
ax.set_ylabel('Ribosome density change\nupon $Lin28a$ knockdown ($\mathrm{log}_2$)', fontsize=12)
ax.set_title('CLIP and ribosome footprinting upon\n$Lin28a$ knockdown', fontsize=14)

plt.show()

# %% [markdown]
# ## Protein localization 반영하기
#
# 논문 그림(Figure 5B, S6A)에서는 protein localization을 반영해서 색으로 나타냈습니다. 이것을 한 번 구현해 봅시다. 각 gene product의 localization을 따로 구하려면 좀 귀찮기 때문에 미리 모아 두었습니다. UniProt에서 매핑된 데이터를 토대로 아주 명확한 것만 일부 정리한 것입니다. 이것도 마찬가지로 처음엔 에러가 나기도 하니까, 다시 실행해보면 거의 잘 됩니다~

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
mouselocal = pd.read_csv('https://hyeshik.qbio.io/binfo/mouselocalization-20210507.txt', sep='\t')
mouselocal.head()
# Out:
#               gene_id            Gene names       type
# 0  ENSMUSG00000000001                 Gnai3  cytoplasm
# 1  ENSMUSG00000000028  Cdc45 Cdc45l Cdc45l2    nucleus
# 2  ENSMUSG00000000049            Apoh B2gp1  cytoplasm
# 3  ENSMUSG00000000058                  Cav2  cytoplasm
# 4  ENSMUSG00000000085                 Scmh1    nucleus

# %% [markdown]
# 이제 이 localization 데이터와 위에서 만든 scatter를 결합해서 논문 그림과 비슷하게 만들어 봅시다.

# %%
cnts_filtered['gene_id'] = cnts_filtered.index.map(lambda x: x.split('.')[0])

cnts_local = pd.merge(cnts_filtered[['gene_id', 'clip_enrichment', 'rden_change']], mouselocal, on='gene_id', how='inner')

cnts_local.head()
# Out:
#               gene_id  clip_enrichment  rden_change            Gene names  \
# 0  ENSMUSG00000025907         2.063023     0.951994   Rb1cc1 Cc1 Kiaa0203
# 1  ENSMUSG00000051285         2.520127     1.577161                Pcmtd1
# 2  ENSMUSG00000025917         0.464287     0.594049  Cops5 Csn5 Jab1 Kic2
# 3  ENSMUSG00000056763         1.990137     0.804924            Cspp1 Cspp
# 4  ENSMUSG00000042414         0.549471     0.694253                Prdm14
#
#         type
# 0    nucleus
# 1  cytoplasm
# 2    nucleus
# 3  cytoplasm
# 4    nucleus

# %%
# 여기에 새로 코드를 작성해서 논문 그림과 비슷하게 만들어 봅시다.

from matplotlib import pyplot as plt
import numpy as np

fig, ax = plt.subplots(1, 1, figsize=(5, 5))
ax.grid(linestyle='--', linewidth=0.5, alpha=0.5)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

cnts_nuc = cnts_local[cnts_local['type']=='nucleus']
cnts_mem = cnts_local[cnts_local['type']=='integral membrane']
cnts_cyto = cnts_local[cnts_local['type']=='cytoplasm']

ax.scatter(np.log2(cnts_nuc['clip_enrichment']),
           np.log2(cnts_nuc['rden_change']), c='blue', s=2, alpha=0.3)
ax.scatter(np.log2(cnts_mem['clip_enrichment']),
           np.log2(cnts_mem['rden_change']), c='red', s=2, alpha=0.3)
ax.scatter(np.log2(cnts_cyto['clip_enrichment']),
           np.log2(cnts_cyto['rden_change']), c='green', s=2, alpha=0.3)


ax.set_xlim(-6, 6)
ax.set_ylim(-4, 4)

ax.set_xticks(range(-6, 7, 3))
ax.set_yticks(range(-4, 5, 2))


lgnd = ax.legend(['nucleus', 'integral membrane', 'cytoplasm'], loc='upper left', fontsize=10)
lgnd.legend_handles[0]._sizes = [40]
lgnd.legend_handles[1]._sizes = [40]
lgnd.legend_handles[2]._sizes = [40]

ax.set_xlabel('Lin28A CLIP enrichment ($\mathrm{log}_2$)', fontsize=12)
ax.set_ylabel('Ribosome density change\nupon $Lin28a$ knockdown ($\mathrm{log}_2$)', fontsize=12)
ax.set_title('CLIP and ribosome footprinting upon\n$Lin28a$ knockdown\n- linkage to localization -', fontsize=14)

plt.show()
